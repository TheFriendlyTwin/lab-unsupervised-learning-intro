# %% [markdown]
# # Lab | Unsupervised learning intro

# %% [markdown]
# ### Instructions

# %% [markdown]
# --------------------------------------------------------------------------------------------------
# It's the moment to perform clustering on the songs you collected. Remember that the ultimate goal of this little project is to improve the recommendations of artists. Clustering the songs will allow the recommendation system to limit the scope of the recommendations to only songs that belong to the same cluster - songs with similar audio features.
#
# The experiments you did with the Spotify API and the Billboard web scraping will allow you to create a pipeline such that when the user enters a song, you:
#
# 1. Check whether or not the song is in the Billboard Hot 200.
# 2. Collect the audio features from the Spotify API.
#
# After that, you want to send the Spotify audio features of the submitted song to the clustering model, which should return a cluster number.
#
# We want to have as many songs as possible to create the clustering model, so we will add the songs you collected to a bigger dataset available on Kaggle containing 160 thousand songs.
#
# --------------------------------------------------------------------------------------------------------

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\mafal\anaconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\mafal\anaconda3\lib\site-packages (from spotipy) (5.0.3)
# Requirement already satisfied: requests>=2.25.0 in c:\users\mafal\anaconda3\lib\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\mafal\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\mafal\anaconda3\lib\site-packages (from spotipy) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mafal\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mafal\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mafal\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2024.2.2)

# %%
# Testing spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="c43ae4f18c0d4b2c8b04c93649fa4b72",
                                                           client_secret="1f7865f1e7aa439e9e997bc38b591855"))

# %%
import numpy as np
import pandas as pd

# Importing the track features csv file
spotify_track_features = pd.read_csv(r"C:\Users\mafal\Documents\ironhack\labs\lab-unsupervised-learning-intro\files_for_lab\spotify_track_features.csv")
spotify_track_features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.695   0.700    1    -1.587     0       0.0332      0.104000
# 1            0.593   0.741    4    -4.353     0       0.0359      0.022100
# 2            0.660   0.765    2    -6.217     1       0.0299      0.125000
# 3            0.577   0.891    0    -4.672     1       0.0359      0.001230
# 4            0.531   0.693    6    -5.203     0       0.0374      0.009310
# ...            ...     ...  ...       ...   ...          ...           ...
# 3003         0.406   0.807    7    -3.871     1       0.0507      0.008350
# 3004         0.502   0.961    9    -4.389     1       0.0905      0.000075
# 3005         0.639   0.832    1    -4.976     1       0.1180      0.003080
# 3006         0.741   0.810   11    -5.808     0       0.1650      0.002650
# 3007         0.597   0.888   10    -1.706     0       0.0724      0.010200
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000     0.192    0.461   94.959  audio_features
# 1             0.000000     0.393    0.460   96.978  audio_features
# 2             0.000956     0.235    0.681  123.051  audio_features
# 3             0.000000     0.114    0.846  144.989  audio_features
# 4             0.000003     0.119    0.555  157.960  audio_features
# ...                ...       ...      ...      ...             ...
# 3003          0.000000     0.118    0.290  159.713  audio_features
# 3004          0.000002     0.124    0.281  110.028  audio_features
# 3005          0.000382     0.121    0.482  119.045  audio_features
# 3006          0.018400     0.131    0.799  132.076  audio_features
# 3007          0.009640     0.268    0.595  127.999  audio_features
#
#                           id                                   uri  \
# 0     2ikmBwZKZr0ahGcX4x8qtj  spotify:track:2ikmBwZKZr0ahGcX4x8qtj
# 1     2MxErftY5S07dFtIdxQOSF  spotify:track:2MxErftY5S07dFtIdxQOSF
# 2     19meO0ADnoTjRuBMXZCdbs  spotify:track:19meO0ADnoTjRuBMXZCdbs
# 3     3OPyobYAM5MgTm35AJV99O  spotify:track:3OPyobYAM5MgTm35AJV99O
# 4     4nDfJDZaUVtwOSnGROb2GN  spotify:track:4nDfJDZaUVtwOSnGROb2GN
# ...                      ...                                   ...
# 3003  38ODYA4I5jEhFr4xJJd1RG  spotify:track:38ODYA4I5jEhFr4xJJd1RG
# 3004  3oGNDHK33fp1GMqU9e4HQ7  spotify:track:3oGNDHK33fp1GMqU9e4HQ7
# 3005  2jPqRiw1kJvxDKIibCPhHu  spotify:track:2jPqRiw1kJvxDKIibCPhHu
# 3006  0mH0iiNINYULYFwszeqWnW  spotify:track:0mH0iiNINYULYFwszeqWnW
# 3007  12dYN0rS95O37qxZh3pOLV  spotify:track:12dYN0rS95O37qxZh3pOLV
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2ikmBwZKZr0a...
# 1     https://api.spotify.com/v1/tracks/2MxErftY5S07...
# 2     https://api.spotify.com/v1/tracks/19meO0ADnoTj...
# 3     https://api.spotify.com/v1/tracks/3OPyobYAM5Mg...
# 4     https://api.spotify.com/v1/tracks/4nDfJDZaUVtw...
# ...                                                 ...
# 3003  https://api.spotify.com/v1/tracks/38ODYA4I5jEh...
# 3004  https://api.spotify.com/v1/tracks/3oGNDHK33fp1...
# 3005  https://api.spotify.com/v1/tracks/2jPqRiw1kJvx...
# 3006  https://api.spotify.com/v1/tracks/0mH0iiNINYUL...
# 3007  https://api.spotify.com/v1/tracks/12dYN0rS95O3...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2ikm...       183296
# 1     https://api.spotify.com/v1/audio-analysis/2MxE...       220670
# 2     https://api.spotify.com/v1/audio-analysis/19me...       175333
# 3     https://api.spotify.com/v1/audio-analysis/3OPy...       155707
# 4     https://api.spotify.com/v1/audio-analysis/4nDf...       164453
# ...                                                 ...          ...
# 3003  https://api.spotify.com/v1/audio-analysis/38OD...       226861
# 3004  https://api.spotify.com/v1/audio-analysis/3oGN...       234550
# 3005  https://api.spotify.com/v1/audio-analysis/2jPq...       166467
# 3006  https://api.spotify.com/v1/audio-analysis/0mH0...       125455
# 3007  https://api.spotify.com/v1/audio-analysis/12dY...       244258
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3003               3
# 3004               4
# 3005               4
# 3006               4
# 3007               4
#
# [3008 rows x 18 columns]

# %%
# Checking what columns does the track features df contains
spotify_track_features.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
# Importing the track data csv file
spotify_track_data = pd.read_csv(r"C:\Users\mafal\Documents\ironhack\labs\lab-unsupervised-learning-intro\files_for_lab\spotify_track_data.csv")
spotify_track_data
# Out:
#                                                 artists  \
# 0     [{'external_urls': {'spotify': 'https://open.s...
# 1     [{'external_urls': {'spotify': 'https://open.s...
# 2     [{'external_urls': {'spotify': 'https://open.s...
# 3     [{'external_urls': {'spotify': 'https://open.s...
# 4     [{'external_urls': {'spotify': 'https://open.s...
# ...                                                 ...
# 3003  [{'external_urls': {'spotify': 'https://open.s...
# 3004  [{'external_urls': {'spotify': 'https://open.s...
# 3005  [{'external_urls': {'spotify': 'https://open.s...
# 3006  [{'external_urls': {'spotify': 'https://open.s...
# 3007  [{'external_urls': {'spotify': 'https://open.s...
#
#                                       available_markets  disc_number  \
# 0     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 1     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 2     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 4     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# ...                                                 ...          ...
# 3003  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3004  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3005  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CL...            1
# 3006  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3007  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
#
#       duration_ms  explicit  \
# 0          198123     False
# 1          188808     False
# 2          195226     False
# 3           93251     False
# 4          155706      True
# ...           ...       ...
# 3003       199906      True
# 3004       210240     False
# 3005       157333     False
# 3006       225306      True
# 3007       166653      True
#
#                                                    href  \
# 0     https://api.spotify.com/v1/tracks/7hgIaQykdol1...
# 1     https://api.spotify.com/v1/tracks/4pYiIZn2DKrK...
# 2     https://api.spotify.com/v1/tracks/3xeyZGEEVW8S...
# 3     https://api.spotify.com/v1/tracks/1mj4y7NHlTq6...
# 4     https://api.spotify.com/v1/tracks/3OPyobYAM5Mg...
# ...                                                 ...
# 3003  https://api.spotify.com/v1/tracks/5W8YXBz9MTID...
# 3004  https://api.spotify.com/v1/tracks/2DlHlPMa4M17...
# 3005  https://api.spotify.com/v1/tracks/3K4HG9evC7dg...
# 3006  https://api.spotify.com/v1/tracks/6nJPHXRpKYv2...
# 3007  https://api.spotify.com/v1/tracks/2YC6ET3q1F29...
#
#                           id  is_local                         name  \
# 0     7hgIaQykdol1sWnj1uqBup     False                 CULT CLASSIC
# 1     4pYiIZn2DKrK8MBYuS946R     False                  BACKSTABBER
# 2     3xeyZGEEVW8SZPmteR9Fw6     False                 Love Goes On
# 3     1mj4y7NHlTq6YfTZOeNqOx     False                     Tornillo
# 4     3OPyobYAM5MgTm35AJV99O     False  you don't like me like that
# ...                      ...       ...                          ...
# 3003  5W8YXBz9MTIDyrpYaCg2Ky     False                  Last Resort
# 3004  2DlHlPMa4M17kufBvI2lEN     False                   Chop Suey!
# 3005  3K4HG9evC7dg3N0R9cYqk4     False              One Step Closer
# 3006  6nJPHXRpKYv2yqtalEjKy5     False                 Got the Life
# 3007  2YC6ET3q1F29B0V7UcPV70     False                  Break Stuff
#
#       popularity  ...                     album.name  album.release_date  \
# 0             31  ...                   Cult Classic          2023-11-10
# 1             31  ...                    BACKSTABBER          2024-01-05
# 2             31  ...                   Love Goes On          2023-05-12
# 3             31  ...                       Tornillo          2023-11-16
# 4             31  ...    you don't like me like that          2023-05-19
# ...          ...  ...                            ...                 ...
# 3003          81  ...                         Infest          2001-04-25
# 3004          85  ...                       Toxicity          2001-09-04
# 3005          82  ...  Hybrid Theory (Bonus Edition)                2000
# 3006          73  ...              Follow The Leader          1998-08-18
# 3007          57  ...                  Greatest Hitz          2005-01-01
#
#      album.release_date_precision album.total_tracks album.type  \
# 0                             day                  6      album
# 1                             day                  1      album
# 2                             day                  1      album
# 3                             day                  1      album
# 4                             day                  2      album
# ...                           ...                ...        ...
# 3003                          day                 13      album
# 3004                          day                 15      album
# 3005                         year                 15      album
# 3006                          day                 14      album
# 3007                          day                 17      album
#
#                                  album.uri external_ids.isrc  \
# 0     spotify:album:3vw9IZ3YV2T5bqYTYG0IXr      QMRSZ2302147
# 1     spotify:album:1RFijpHOUqGPZ3hdvcm8IM      QZWFH2374284
# 2     spotify:album:30eJbXVjjtYtYtwkt337Sr      QZQAY2345784
# 3     spotify:album:6MSMis63C7wWLVSSmSl92b      USHR22316801
# 4     spotify:album:35YQAprIaYWKCWtr7iS5UT      USHR22316102
# ...                                    ...               ...
# 3003  spotify:album:0BHa0ePkvGAVKymB4FU58m      USDW10021712
# 3004  spotify:album:6jWde94ln40epKIQCd8XUh      USSM10107256
# 3005  spotify:album:6hPkbAV3ZXpGZBGUvL6jVM      USWB10002399
# 3006  spotify:album:0gsiszk6JWYwAyGvaTTud4      USSM19801763
# 3007  spotify:album:50na3UenOpUOS1uuWXM0AY      USIR19902309
#
#                                   external_urls.spotify  \
# 0     https://open.spotify.com/track/7hgIaQykdol1sWn...
# 1     https://open.spotify.com/track/4pYiIZn2DKrK8MB...
# 2     https://open.spotify.com/track/3xeyZGEEVW8SZPm...
# 3     https://open.spotify.com/track/1mj4y7NHlTq6YfT...
# 4     https://open.spotify.com/track/3OPyobYAM5MgTm3...
# ...                                                 ...
# 3003  https://open.spotify.com/track/5W8YXBz9MTIDyrp...
# 3004  https://open.spotify.com/track/2DlHlPMa4M17kuf...
# 3005  https://open.spotify.com/track/3K4HG9evC7dg3N0...
# 3006  https://open.spotify.com/track/6nJPHXRpKYv2yqt...
# 3007  https://open.spotify.com/track/2YC6ET3q1F29B0V...
#
#                       artist_name               artist_id
# 0                       Holy Wars  2dTOWcCL0cYviin0Uz1lj4
# 1                      Ergo, Bria  0AF9HrL08aOaZPsIiO8GmA
# 2     Kelsy Karter & The Heroines  2mAAO54PkHr3NjdlRpzEDl
# 3             Margaritas Podridas  5O9NicFLG2F9Xr7OHxmrb7
# 4                            Zeph  502gYHkFCtLzBIcU4ctPLd
# ...                           ...                     ...
# 3003                   Papa Roach  4RddZ3iHvSpGV4dvATac9X
# 3004             System Of A Down  5eAWCfyUhZtHHtBdNk56l1
# 3005                  Linkin Park  6XyY86QOPPrYVGvF9ch6wz
# 3006                         Korn  3RNrq3jvMZxD9ZyoOZbQOD
# 3007                  Limp Bizkit  165ZgPlLkK7bf5bDoFc6Sb
#
# [3008 rows x 31 columns]

# %%
# Checking what columns does the track data df contains
spotify_track_data.columns
# Out:
# Index(['artists', 'available_markets', 'disc_number', 'duration_ms',
#        'explicit', 'href', 'id', 'is_local', 'name', 'popularity',
#        'preview_url', 'track_number', 'type', 'uri', 'album.album_type',
#        'album.artists', 'album.available_markets',
#        'album.external_urls.spotify', 'album.href', 'album.id', 'album.images',
#        'album.name', 'album.release_date', 'album.release_date_precision',
#        'album.total_tracks', 'album.type', 'album.uri', 'external_ids.isrc',
#        'external_urls.spotify', 'artist_name', 'artist_id'],
#       dtype='object')

# %%
spotify_track_data[['id', 'name', 'artist_name', 'artist_id']]
# Out:
#                           id                         name  \
# 0     7hgIaQykdol1sWnj1uqBup                 CULT CLASSIC
# 1     4pYiIZn2DKrK8MBYuS946R                  BACKSTABBER
# 2     3xeyZGEEVW8SZPmteR9Fw6                 Love Goes On
# 3     1mj4y7NHlTq6YfTZOeNqOx                     Tornillo
# 4     3OPyobYAM5MgTm35AJV99O  you don't like me like that
# ...                      ...                          ...
# 3003  5W8YXBz9MTIDyrpYaCg2Ky                  Last Resort
# 3004  2DlHlPMa4M17kufBvI2lEN                   Chop Suey!
# 3005  3K4HG9evC7dg3N0R9cYqk4              One Step Closer
# 3006  6nJPHXRpKYv2yqtalEjKy5                 Got the Life
# 3007  2YC6ET3q1F29B0V7UcPV70                  Break Stuff
#
#                       artist_name               artist_id
# 0                       Holy Wars  2dTOWcCL0cYviin0Uz1lj4
# 1                      Ergo, Bria  0AF9HrL08aOaZPsIiO8GmA
# 2     Kelsy Karter & The Heroines  2mAAO54PkHr3NjdlRpzEDl
# 3             Margaritas Podridas  5O9NicFLG2F9Xr7OHxmrb7
# 4                            Zeph  502gYHkFCtLzBIcU4ctPLd
# ...                           ...                     ...
# 3003                   Papa Roach  4RddZ3iHvSpGV4dvATac9X
# 3004             System Of A Down  5eAWCfyUhZtHHtBdNk56l1
# 3005                  Linkin Park  6XyY86QOPPrYVGvF9ch6wz
# 3006                         Korn  3RNrq3jvMZxD9ZyoOZbQOD
# 3007                  Limp Bizkit  165ZgPlLkK7bf5bDoFc6Sb
#
# [3008 rows x 4 columns]

# %% [markdown]
# ------------------------------------------------------------------------------------------------
# We need to get the audio features from the songs we extract on the Web Scraping lab.
#
# ----------------------------------------------------------------------------------------------

# %%
# Importing the other track features csv file
other_track_features = pd.read_csv(r"C:\Users\mafal\Documents\ironhack\labs\lab-unsupervised-learning-intro\files_for_lab\other_track_features.csv")
other_track_features
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.864   0.476    1   -10.068     1       0.4360       0.03740
# 1           0.545   0.641   10    -6.398     0       0.0998       0.00453
# 2           0.629   0.698    8    -4.485     1       0.3080       0.05090
# 3           0.732   0.703   11    -7.224     1       0.0314       0.10400
# 4           0.827   0.768    0    -5.702     1       0.2650       0.79000
# ..            ...     ...  ...       ...   ...          ...           ...
# 148         0.645   0.531    8    -6.239     1       0.0272       0.08520
# 149         0.582   0.537    0    -9.229     1       0.6190       0.12900
# 150         0.429   0.181    3   -12.005     1       0.0412       0.73400
# 151         0.569   0.480    7    -7.533     1       0.0412       0.78100
# 152         0.631   0.518    0    -8.771     1       0.0303       0.27400
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.3740    0.647  157.144  audio_features
# 1            0.000066    0.1710    0.464  121.892  audio_features
# 2            0.001660    0.0909    0.599  117.765  audio_features
# 3            0.041700    0.1090    0.836  108.979  audio_features
# 4            0.000024    0.4970    0.734   99.988  audio_features
# ..                ...       ...      ...      ...             ...
# 148          0.000004    0.1550    0.537  125.986  audio_features
# 149          0.000000    0.0749    0.771   82.103  audio_features
# 150          0.000008    0.1010    0.259   80.106  audio_features
# 151          0.082200    0.1000    0.353  123.700  audio_features
# 152          0.000000    0.0880    0.205   93.023  audio_features
#
#                          id                                   uri  \
# 0    1vrFJDrysqmsNAgyjBzx4f  spotify:track:1vrFJDrysqmsNAgyjBzx4f
# 1    1Hohk6AufHZOrrhMXZppax  spotify:track:1Hohk6AufHZOrrhMXZppax
# 2    0UvZcEfpzVyx47QsRbjyBz  spotify:track:0UvZcEfpzVyx47QsRbjyBz
# 3    5DRnssBoVo8e7uAQZkNT8O  spotify:track:5DRnssBoVo8e7uAQZkNT8O
# 4    2FYGZDfsAnNsrm1gVbyKnG  spotify:track:2FYGZDfsAnNsrm1gVbyKnG
# ..                      ...                                   ...
# 148  6ZXH6YfcouRBWanewWxuuz  spotify:track:6ZXH6YfcouRBWanewWxuuz
# 149  0nqhKXDjsyBMvbeWmgijD0  spotify:track:0nqhKXDjsyBMvbeWmgijD0
# 150  1AU6deCmEZI4di2DzzEt0U  spotify:track:1AU6deCmEZI4di2DzzEt0U
# 151  3cJI6VFdyRdriDVwB0sU3Y  spotify:track:3cJI6VFdyRdriDVwB0sU3Y
# 152  5enxwA8aAbwZbf5qCHORXi  spotify:track:5enxwA8aAbwZbf5qCHORXi
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1vrFJDrysqms...
# 1    https://api.spotify.com/v1/tracks/1Hohk6AufHZO...
# 2    https://api.spotify.com/v1/tracks/0UvZcEfpzVyx...
# 3    https://api.spotify.com/v1/tracks/5DRnssBoVo8e...
# 4    https://api.spotify.com/v1/tracks/2FYGZDfsAnNs...
# ..                                                 ...
# 148  https://api.spotify.com/v1/tracks/6ZXH6YfcouRB...
# 149  https://api.spotify.com/v1/tracks/0nqhKXDjsyBM...
# 150  https://api.spotify.com/v1/tracks/1AU6deCmEZI4...
# 151  https://api.spotify.com/v1/tracks/3cJI6VFdyRdr...
# 152  https://api.spotify.com/v1/tracks/5enxwA8aAbwZ...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1vrF...       137580
# 1    https://api.spotify.com/v1/audio-analysis/1Hoh...       215460
# 2    https://api.spotify.com/v1/audio-analysis/0UvZ...       201816
# 3    https://api.spotify.com/v1/audio-analysis/5DRn...       156772
# 4    https://api.spotify.com/v1/audio-analysis/2FYG...       137533
# ..                                                 ...          ...
# 148  https://api.spotify.com/v1/audio-analysis/6ZXH...       189027
# 149  https://api.spotify.com/v1/audio-analysis/0nqh...       180930
# 150  https://api.spotify.com/v1/audio-analysis/1AU6...       316170
# 151  https://api.spotify.com/v1/audio-analysis/3cJI...       234827
# 152  https://api.spotify.com/v1/audio-analysis/5enx...       613027
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 148               3
# 149               4
# 150               4
# 151               5
# 152               4
#
# [153 rows x 18 columns]

# %%
# Importing the other track data csv file
other_track_data = pd.read_csv(r"C:\Users\mafal\Documents\ironhack\labs\lab-unsupervised-learning-intro\files_for_lab\other_track_data.csv")
other_track_data
# Out:
#                                                artists  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 151  [{'external_urls': {'spotify': 'https://open.s...
# 152  [{'external_urls': {'spotify': 'https://open.s...
# 153  [{'external_urls': {'spotify': 'https://open.s...
# 154  [{'external_urls': {'spotify': 'https://open.s...
# 155  [{'external_urls': {'spotify': 'https://open.s...
#
#                                      available_markets  disc_number  \
# 0    ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 1    ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 2    ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3    ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 4    ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# ..                                                 ...          ...
# 151  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 152  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 153  ['AR', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL...            1
# 154  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 155  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
#
#      duration_ms  explicit                                               href  \
# 0         137579      True  https://api.spotify.com/v1/tracks/1vrFJDrysqms...
# 1         215459      True  https://api.spotify.com/v1/tracks/1Hohk6AufHZO...
# 2         201816      True  https://api.spotify.com/v1/tracks/0UvZcEfpzVyx...
# 3         156772     False  https://api.spotify.com/v1/tracks/5DRnssBoVo8e...
# 4         137533      True  https://api.spotify.com/v1/tracks/2FYGZDfsAnNs...
# ..           ...       ...                                                ...
# 151       189026     False  https://api.spotify.com/v1/tracks/6ZXH6YfcouRB...
# 152       180930      True  https://api.spotify.com/v1/tracks/0nqhKXDjsyBM...
# 153       316169     False  https://api.spotify.com/v1/tracks/1AU6deCmEZI4...
# 154       234826     False  https://api.spotify.com/v1/tracks/3cJI6VFdyRdr...
# 155       613026      True  https://api.spotify.com/v1/tracks/5enxwA8aAbwZ...
#
#                          id  is_local  \
# 0    1vrFJDrysqmsNAgyjBzx4f     False
# 1    1Hohk6AufHZOrrhMXZppax     False
# 2    0UvZcEfpzVyx47QsRbjyBz     False
# 3    5DRnssBoVo8e7uAQZkNT8O     False
# 4    2FYGZDfsAnNsrm1gVbyKnG     False
# ..                      ...       ...
# 151  6ZXH6YfcouRBWanewWxuuz     False
# 152  0nqhKXDjsyBMvbeWmgijD0     False
# 153  1AU6deCmEZI4di2DzzEt0U     False
# 154  3cJI6VFdyRdriDVwB0sU3Y     False
# 155  5enxwA8aAbwZbf5qCHORXi     False
#
#                                                   name  popularity  ...  \
# 0                                    F.N.F. (Let's Go)          59  ...
# 1                                      ALIEN SUPERSTAR          73  ...
# 2                                            El Apagón          70  ...
# 3                                               Runner          54  ...
# 4                                                SAOKO          66  ...
# ..                                                 ...         ...  ...
# 151                                           Automate          32  ...
# 152                                           Wockesha          64  ...
# 153                                         Baby Grand           9  ...
# 154                    Avalon (with Francesco Turrisi)          20  ...
# 155  All Too Well (10 Minute Version) (Taylor's Ver...          84  ...
#
#     album.release_date  album.release_date_precision album.total_tracks  \
# 0           2022-05-03                           day                  1
# 1           2022-07-29                           day                 16
# 2           2022-05-06                           day                 23
# 3           2022-09-23                           day                 13
# 4           2022-03-18                           day                 16
# ..                 ...                           ...                ...
# 151         2021-11-05                           day                 10
# 152         2021-04-23                           day                 22
# 153         2021-01-29                           day                 10
# 154         2021-04-09                           day                 12
# 155         2021-11-12                           day                 30
#
#     album.type                             album.uri external_ids.isrc  \
# 0        album  spotify:album:1FkcZKerCfWg4nUItVHf9B      QZRD92201643
# 1        album  spotify:album:6FJxoadUE4JNVwWHghBwnb      USSM12206231
# 2        album  spotify:album:3RQQmkQEvNCY4prGKE6oc5      QM6MZ2214890
# 3        album  spotify:album:6TzgWk5HZItbFmMT7hH4bU      GBCEL2200057
# 4        album  spotify:album:6jbtHi5R0jMXoliU2OS0lo      USSM12109218
# ..         ...                                   ...               ...
# 151      album  spotify:album:0zNWhYDalgisc4uweLIGZJ      USMTD2100282
# 152      album  spotify:album:5ffogo3K3fYibGWa93IzUe      USUM72105621
# 153      album  spotify:album:3Jr2EYny7lPAoB1XPWaxe5      DED622000036
# 154      album  spotify:album:75qSKqLqEt7zOei7If7Lms      USNO12100014
# 155      album  spotify:album:6kZ42qRrzov54LcAk4onW9      USUG12103690
#
#                                  external_urls.spotify       artist_name  \
# 0    https://open.spotify.com/track/1vrFJDrysqmsNAg...           Hitkidd
# 1    https://open.spotify.com/track/1Hohk6AufHZOrrh...           Beyoncé
# 2    https://open.spotify.com/track/0UvZcEfpzVyx47Q...         Bad Bunny
# 3    https://open.spotify.com/track/5DRnssBoVo8e7uA...            Alex G
# 4    https://open.spotify.com/track/2FYGZDfsAnNsrm1...           ROSALÍA
# ..                                                 ...               ...
# 151  https://open.spotify.com/track/6ZXH6YfcouRBWan...        Snail Mail
# 152  https://open.spotify.com/track/0nqhKXDjsyBMvbe...      Moneybagg Yo
# 153  https://open.spotify.com/track/1AU6deCmEZI4di2...     Anna B Savage
# 154  https://open.spotify.com/track/3cJI6VFdyRdriDV...  Rhiannon Giddens
# 155  https://open.spotify.com/track/5enxwA8aAbwZbf5...      Taylor Swift
#
#                   artist_id                                       artist_genre
# 0    5pR1zWq3UPsOpW1pTWayLf                                ['memphis hip hop']
# 1    6vWDO969PvNqNYHIOW5v0m                                     ['pop', 'r&b']
# 2    4q3ewBCX7sLwd24euuV69X      ['reggaeton', 'trap latino', 'urbano latino']
# 3    6lcwlkAjBPSKnFBZjjZFJs                     ['philly indie', 'pov: indie']
# 4    7ltDVBr6mKbRvohxheJ9h1                          ['pop', 'r&b en espanol']
# ..                      ...                                                ...
# 151  4QkSD9TRUnMtI8Fq1jXJJe  ['art pop', 'baltimore indie', 'bubblegrunge',...
# 152  3tJoFztHeIJkJWMrx0td2f  ['memphis hip hop', 'rap', 'southern hip hop',...
# 153  6nbtlXRy0S6adYpDVoRdNi                                                 []
# 154  1EI0NtLHoh9KBziYCeN1vM  ['black americana', 'folk', 'new americana', '...
# 155  06HL4z0CvFAxyc27GXpf02                                            ['pop']
#
# [156 rows x 32 columns]

# %% [markdown]
# --------------------------------------------------------------------------------------------------------
# Let's now concat both dfs spotify tracks and other tracks to get a larger dataset for our song recommender.
#
# --------------------------------------------------------------------------------------------------------

# %%
# Concatenate DataFrames by appending rows
track_features = pd.concat([spotify_track_features, other_track_features], ignore_index=True)
track_features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.695   0.700    1    -1.587     0       0.0332       0.10400
# 1            0.593   0.741    4    -4.353     0       0.0359       0.02210
# 2            0.660   0.765    2    -6.217     1       0.0299       0.12500
# 3            0.577   0.891    0    -4.672     1       0.0359       0.00123
# 4            0.531   0.693    6    -5.203     0       0.0374       0.00931
# ...            ...     ...  ...       ...   ...          ...           ...
# 3156         0.645   0.531    8    -6.239     1       0.0272       0.08520
# 3157         0.582   0.537    0    -9.229     1       0.6190       0.12900
# 3158         0.429   0.181    3   -12.005     1       0.0412       0.73400
# 3159         0.569   0.480    7    -7.533     1       0.0412       0.78100
# 3160         0.631   0.518    0    -8.771     1       0.0303       0.27400
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1920    0.461   94.959  audio_features
# 1             0.000000    0.3930    0.460   96.978  audio_features
# 2             0.000956    0.2350    0.681  123.051  audio_features
# 3             0.000000    0.1140    0.846  144.989  audio_features
# 4             0.000003    0.1190    0.555  157.960  audio_features
# ...                ...       ...      ...      ...             ...
# 3156          0.000004    0.1550    0.537  125.986  audio_features
# 3157          0.000000    0.0749    0.771   82.103  audio_features
# 3158          0.000008    0.1010    0.259   80.106  audio_features
# 3159          0.082200    0.1000    0.353  123.700  audio_features
# 3160          0.000000    0.0880    0.205   93.023  audio_features
#
#                           id                                   uri  \
# 0     2ikmBwZKZr0ahGcX4x8qtj  spotify:track:2ikmBwZKZr0ahGcX4x8qtj
# 1     2MxErftY5S07dFtIdxQOSF  spotify:track:2MxErftY5S07dFtIdxQOSF
# 2     19meO0ADnoTjRuBMXZCdbs  spotify:track:19meO0ADnoTjRuBMXZCdbs
# 3     3OPyobYAM5MgTm35AJV99O  spotify:track:3OPyobYAM5MgTm35AJV99O
# 4     4nDfJDZaUVtwOSnGROb2GN  spotify:track:4nDfJDZaUVtwOSnGROb2GN
# ...                      ...                                   ...
# 3156  6ZXH6YfcouRBWanewWxuuz  spotify:track:6ZXH6YfcouRBWanewWxuuz
# 3157  0nqhKXDjsyBMvbeWmgijD0  spotify:track:0nqhKXDjsyBMvbeWmgijD0
# 3158  1AU6deCmEZI4di2DzzEt0U  spotify:track:1AU6deCmEZI4di2DzzEt0U
# 3159  3cJI6VFdyRdriDVwB0sU3Y  spotify:track:3cJI6VFdyRdriDVwB0sU3Y
# 3160  5enxwA8aAbwZbf5qCHORXi  spotify:track:5enxwA8aAbwZbf5qCHORXi
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2ikmBwZKZr0a...
# 1     https://api.spotify.com/v1/tracks/2MxErftY5S07...
# 2     https://api.spotify.com/v1/tracks/19meO0ADnoTj...
# 3     https://api.spotify.com/v1/tracks/3OPyobYAM5Mg...
# 4     https://api.spotify.com/v1/tracks/4nDfJDZaUVtw...
# ...                                                 ...
# 3156  https://api.spotify.com/v1/tracks/6ZXH6YfcouRB...
# 3157  https://api.spotify.com/v1/tracks/0nqhKXDjsyBM...
# 3158  https://api.spotify.com/v1/tracks/1AU6deCmEZI4...
# 3159  https://api.spotify.com/v1/tracks/3cJI6VFdyRdr...
# 3160  https://api.spotify.com/v1/tracks/5enxwA8aAbwZ...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2ikm...       183296
# 1     https://api.spotify.com/v1/audio-analysis/2MxE...       220670
# 2     https://api.spotify.com/v1/audio-analysis/19me...       175333
# 3     https://api.spotify.com/v1/audio-analysis/3OPy...       155707
# 4     https://api.spotify.com/v1/audio-analysis/4nDf...       164453
# ...                                                 ...          ...
# 3156  https://api.spotify.com/v1/audio-analysis/6ZXH...       189027
# 3157  https://api.spotify.com/v1/audio-analysis/0nqh...       180930
# 3158  https://api.spotify.com/v1/audio-analysis/1AU6...       316170
# 3159  https://api.spotify.com/v1/audio-analysis/3cJI...       234827
# 3160  https://api.spotify.com/v1/audio-analysis/5enx...       613027
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3156               3
# 3157               4
# 3158               4
# 3159               5
# 3160               4
#
# [3161 rows x 18 columns]

# %%
print(track_features['type'].unique())
# Out:
# ['audio_features']

# %%
# Concatenate DataFrames by appending rows
track_data = pd.concat([spotify_track_data, other_track_data], ignore_index=True)
track_data
# Out:
#                                                 artists  \
# 0     [{'external_urls': {'spotify': 'https://open.s...
# 1     [{'external_urls': {'spotify': 'https://open.s...
# 2     [{'external_urls': {'spotify': 'https://open.s...
# 3     [{'external_urls': {'spotify': 'https://open.s...
# 4     [{'external_urls': {'spotify': 'https://open.s...
# ...                                                 ...
# 3159  [{'external_urls': {'spotify': 'https://open.s...
# 3160  [{'external_urls': {'spotify': 'https://open.s...
# 3161  [{'external_urls': {'spotify': 'https://open.s...
# 3162  [{'external_urls': {'spotify': 'https://open.s...
# 3163  [{'external_urls': {'spotify': 'https://open.s...
#
#                                       available_markets  disc_number  \
# 0     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 1     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 2     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 4     ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# ...                                                 ...          ...
# 3159  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3160  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3161  ['AR', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL...            1
# 3162  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 3163  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
#
#       duration_ms  explicit  \
# 0          198123     False
# 1          188808     False
# 2          195226     False
# 3           93251     False
# 4          155706      True
# ...           ...       ...
# 3159       189026     False
# 3160       180930      True
# 3161       316169     False
# 3162       234826     False
# 3163       613026      True
#
#                                                    href  \
# 0     https://api.spotify.com/v1/tracks/7hgIaQykdol1...
# 1     https://api.spotify.com/v1/tracks/4pYiIZn2DKrK...
# 2     https://api.spotify.com/v1/tracks/3xeyZGEEVW8S...
# 3     https://api.spotify.com/v1/tracks/1mj4y7NHlTq6...
# 4     https://api.spotify.com/v1/tracks/3OPyobYAM5Mg...
# ...                                                 ...
# 3159  https://api.spotify.com/v1/tracks/6ZXH6YfcouRB...
# 3160  https://api.spotify.com/v1/tracks/0nqhKXDjsyBM...
# 3161  https://api.spotify.com/v1/tracks/1AU6deCmEZI4...
# 3162  https://api.spotify.com/v1/tracks/3cJI6VFdyRdr...
# 3163  https://api.spotify.com/v1/tracks/5enxwA8aAbwZ...
#
#                           id  is_local  \
# 0     7hgIaQykdol1sWnj1uqBup     False
# 1     4pYiIZn2DKrK8MBYuS946R     False
# 2     3xeyZGEEVW8SZPmteR9Fw6     False
# 3     1mj4y7NHlTq6YfTZOeNqOx     False
# 4     3OPyobYAM5MgTm35AJV99O     False
# ...                      ...       ...
# 3159  6ZXH6YfcouRBWanewWxuuz     False
# 3160  0nqhKXDjsyBMvbeWmgijD0     False
# 3161  1AU6deCmEZI4di2DzzEt0U     False
# 3162  3cJI6VFdyRdriDVwB0sU3Y     False
# 3163  5enxwA8aAbwZbf5qCHORXi     False
#
#                                                    name  popularity  ...  \
# 0                                          CULT CLASSIC          31  ...
# 1                                           BACKSTABBER          31  ...
# 2                                          Love Goes On          31  ...
# 3                                              Tornillo          31  ...
# 4                           you don't like me like that          31  ...
# ...                                                 ...         ...  ...
# 3159                                           Automate          32  ...
# 3160                                           Wockesha          64  ...
# 3161                                         Baby Grand           9  ...
# 3162                    Avalon (with Francesco Turrisi)          20  ...
# 3163  All Too Well (10 Minute Version) (Taylor's Ver...          84  ...
#
#      album.release_date  album.release_date_precision album.total_tracks  \
# 0            2023-11-10                           day                  6
# 1            2024-01-05                           day                  1
# 2            2023-05-12                           day                  1
# 3            2023-11-16                           day                  1
# 4            2023-05-19                           day                  2
# ...                 ...                           ...                ...
# 3159         2021-11-05                           day                 10
# 3160         2021-04-23                           day                 22
# 3161         2021-01-29                           day                 10
# 3162         2021-04-09                           day                 12
# 3163         2021-11-12                           day                 30
#
#      album.type                             album.uri external_ids.isrc  \
# 0         album  spotify:album:3vw9IZ3YV2T5bqYTYG0IXr      QMRSZ2302147
# 1         album  spotify:album:1RFijpHOUqGPZ3hdvcm8IM      QZWFH2374284
# 2         album  spotify:album:30eJbXVjjtYtYtwkt337Sr      QZQAY2345784
# 3         album  spotify:album:6MSMis63C7wWLVSSmSl92b      USHR22316801
# 4         album  spotify:album:35YQAprIaYWKCWtr7iS5UT      USHR22316102
# ...         ...                                   ...               ...
# 3159      album  spotify:album:0zNWhYDalgisc4uweLIGZJ      USMTD2100282
# 3160      album  spotify:album:5ffogo3K3fYibGWa93IzUe      USUM72105621
# 3161      album  spotify:album:3Jr2EYny7lPAoB1XPWaxe5      DED622000036
# 3162      album  spotify:album:75qSKqLqEt7zOei7If7Lms      USNO12100014
# 3163      album  spotify:album:6kZ42qRrzov54LcAk4onW9      USUG12103690
#
#                                   external_urls.spotify  \
# 0     https://open.spotify.com/track/7hgIaQykdol1sWn...
# 1     https://open.spotify.com/track/4pYiIZn2DKrK8MB...
# 2     https://open.spotify.com/track/3xeyZGEEVW8SZPm...
# 3     https://open.spotify.com/track/1mj4y7NHlTq6YfT...
# 4     https://open.spotify.com/track/3OPyobYAM5MgTm3...
# ...                                                 ...
# 3159  https://open.spotify.com/track/6ZXH6YfcouRBWan...
# 3160  https://open.spotify.com/track/0nqhKXDjsyBMvbe...
# 3161  https://open.spotify.com/track/1AU6deCmEZI4di2...
# 3162  https://open.spotify.com/track/3cJI6VFdyRdriDV...
# 3163  https://open.spotify.com/track/5enxwA8aAbwZbf5...
#
#                       artist_name               artist_id  \
# 0                       Holy Wars  2dTOWcCL0cYviin0Uz1lj4
# 1                      Ergo, Bria  0AF9HrL08aOaZPsIiO8GmA
# 2     Kelsy Karter & The Heroines  2mAAO54PkHr3NjdlRpzEDl
# 3             Margaritas Podridas  5O9NicFLG2F9Xr7OHxmrb7
# 4                            Zeph  502gYHkFCtLzBIcU4ctPLd
# ...                           ...                     ...
# 3159                   Snail Mail  4QkSD9TRUnMtI8Fq1jXJJe
# 3160                 Moneybagg Yo  3tJoFztHeIJkJWMrx0td2f
# 3161                Anna B Savage  6nbtlXRy0S6adYpDVoRdNi
# 3162             Rhiannon Giddens  1EI0NtLHoh9KBziYCeN1vM
# 3163                 Taylor Swift  06HL4z0CvFAxyc27GXpf02
#
#                                            artist_genre
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3159  ['art pop', 'baltimore indie', 'bubblegrunge',...
# 3160  ['memphis hip hop', 'rap', 'southern hip hop',...
# 3161                                                 []
# 3162  ['black americana', 'folk', 'new americana', '...
# 3163                                            ['pop']
#
# [3164 rows x 32 columns]

# %% [markdown]
# ###### 1. Creating the clusters

# %% [markdown]
# ---------------------------------------------------------------------------------------------
# We'll first start by creating the cluster using the track features.
#
# ----------------------------------------------------------------------------------------------------

# %%
X = track_features[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 
                    'duration_ms', 'time_signature']].copy()

# %%
X
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.695   0.700    1    -1.587     0       0.0332       0.10400
# 1            0.593   0.741    4    -4.353     0       0.0359       0.02210
# 2            0.660   0.765    2    -6.217     1       0.0299       0.12500
# 3            0.577   0.891    0    -4.672     1       0.0359       0.00123
# 4            0.531   0.693    6    -5.203     0       0.0374       0.00931
# ...            ...     ...  ...       ...   ...          ...           ...
# 3156         0.645   0.531    8    -6.239     1       0.0272       0.08520
# 3157         0.582   0.537    0    -9.229     1       0.6190       0.12900
# 3158         0.429   0.181    3   -12.005     1       0.0412       0.73400
# 3159         0.569   0.480    7    -7.533     1       0.0412       0.78100
# 3160         0.631   0.518    0    -8.771     1       0.0303       0.27400
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000000    0.1920    0.461   94.959       183296
# 1             0.000000    0.3930    0.460   96.978       220670
# 2             0.000956    0.2350    0.681  123.051       175333
# 3             0.000000    0.1140    0.846  144.989       155707
# 4             0.000003    0.1190    0.555  157.960       164453
# ...                ...       ...      ...      ...          ...
# 3156          0.000004    0.1550    0.537  125.986       189027
# 3157          0.000000    0.0749    0.771   82.103       180930
# 3158          0.000008    0.1010    0.259   80.106       316170
# 3159          0.082200    0.1000    0.353  123.700       234827
# 3160          0.000000    0.0880    0.205   93.023       613027
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3156               3
# 3157               4
# 3158               4
# 3159               5
# 3160               4
#
# [3161 rows x 13 columns]

# %%
# K-Means is a distance based algorithm: we need to scale / normalize:
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(X)

pd.DataFrame(X_prep).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.188139 -0.467066 -1.184953  1.424857 -1.187139 -0.760976  0.012327
# 1  0.551651 -0.257643 -0.335666  0.496538 -1.187139 -0.727932 -0.367133
# 2  0.969736 -0.135053 -0.901857 -0.129054  0.842361 -0.801363  0.109625
# 3  0.451810  0.508541 -1.468048  0.389476  0.842361 -0.727932 -0.463828
# 4  0.164766 -0.502822  0.230524  0.211262 -1.187139 -0.709575 -0.426392
#
#          7         8         9         10        11        12
# 0 -0.431478 -0.175442  0.168173 -1.105236 -0.540963  0.202327
# 1 -0.431478  1.068866  0.163737 -1.040129 -0.095232  0.202327
# 2 -0.427837  0.090753  1.144069 -0.199338 -0.635932  0.202327
# 3 -0.431478 -0.658308  1.875991  0.508109 -0.869996  0.202327
# 4 -0.431467 -0.627355  0.585146  0.926392 -0.765689  0.202327

# %% [markdown]
# ----------------------------------------------------------------------------------------------
# For the number of clusters we'll choose the number of different music genres present in our tracks' list, 27:
# - Nu-Metal
# - Alternative Metal
# - Progressive Metal
# - Black Metal
# - Grunge
# - Punk
# - Pure Pop Punk
# - Alternative Rock
# - Blues Rock
# - Mordern Blues Rock
# - Hard Rock
# - New Alt Rock
# - Mordern Rock
# - Rock Pop
# - Indie
# - Pop
# - Jazz
# - Mordern Jazz
# - Sad Soul
# - Trap
# - Hip-Hop
# - Rap
# - Rap Tuga
# - Alternative Beats
# - Rocktronic
# - Techno Rave
# - Fierce Femmes
#
# ---------------------------------------------------------------------------------------------------

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=27, random_state=42)
kmeans.fit(X_prep)
# Out:
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=27, random_state=42)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([ 5,  5, 12, ..., 26, 26, 11])

# %%
# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     149
# 1     185
# 2     149
# 3     193
# 4      41
# 5     239
# 6      49
# 7     120
# 8      26
# 9      40
# 10    112
# 11     46
# 12    145
# 13     12
# 14    133
# 15     48
# 16    126
# 17    108
# 18    100
# 19    132
# 20    112
# 21    205
# 22    135
# 23    164
# 24    104
# 25    161
# 26    127
# Name: count, dtype: int64

# %%
# Explore the cluster assignment in the original dataset
X_df = pd.DataFrame(X)
X_df["cluster"] = clusters

# Example dictionary that maps original cluster numbers to new ones
# This is a direct mapping (no change), but you can modify as per your requirement
cluster_mapping = {i: i for i in range(27)}

# Applying the mapping
X_df['cluster'] = X_df['cluster'].apply(lambda x: cluster_mapping[x])

X_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.695   0.700    1    -1.587     0       0.0332       0.10400
# 1            0.593   0.741    4    -4.353     0       0.0359       0.02210
# 2            0.660   0.765    2    -6.217     1       0.0299       0.12500
# 3            0.577   0.891    0    -4.672     1       0.0359       0.00123
# 4            0.531   0.693    6    -5.203     0       0.0374       0.00931
# ...            ...     ...  ...       ...   ...          ...           ...
# 3156         0.645   0.531    8    -6.239     1       0.0272       0.08520
# 3157         0.582   0.537    0    -9.229     1       0.6190       0.12900
# 3158         0.429   0.181    3   -12.005     1       0.0412       0.73400
# 3159         0.569   0.480    7    -7.533     1       0.0412       0.78100
# 3160         0.631   0.518    0    -8.771     1       0.0303       0.27400
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000000    0.1920    0.461   94.959       183296
# 1             0.000000    0.3930    0.460   96.978       220670
# 2             0.000956    0.2350    0.681  123.051       175333
# 3             0.000000    0.1140    0.846  144.989       155707
# 4             0.000003    0.1190    0.555  157.960       164453
# ...                ...       ...      ...      ...          ...
# 3156          0.000004    0.1550    0.537  125.986       189027
# 3157          0.000000    0.0749    0.771   82.103       180930
# 3158          0.000008    0.1010    0.259   80.106       316170
# 3159          0.082200    0.1000    0.353  123.700       234827
# 3160          0.000000    0.0880    0.205   93.023       613027
#
#       time_signature  cluster
# 0                  4        5
# 1                  4        5
# 2                  4       12
# 3                  4       12
# 4                  4       21
# ...              ...      ...
# 3156               3       18
# 3157               4       24
# 3158               4       26
# 3159               5       26
# 3160               4       11
#
# [3161 rows x 14 columns]

# %%
# "performance metric"
kmeans.inertia_
# Out:
# 16471.44269392305

# %%
# Choosing the best K

K = range(2, 20)

inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

inertia
# Out:
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [35505.66644143819,
#  32228.53869193905,
#  29826.103578126313,
#  28138.444217430577,
#  26576.89830426013,
#  25133.918958301907,
#  24092.514190344802,
#  23253.404780826677,
#  22509.965324111752,
#  21564.190996078705,
#  20869.14725817284,
#  20443.382349643085,
#  19933.713645166874,
#  19586.22015734143,
#  19148.211275341087,
#  18827.897217053895,
#  18528.40482665381,
#  18212.774993028208]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.show()

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)

silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.show()
# Out:
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ---------------------------------------------------------------------------------------
# Visualizing Results
#
# --------------------------------------------------------------------------------------

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# Transform the data into 2D so we can see
pca = PCA(2)
X_2D = pca.fit_transform(X_prep)
X_2D
# Out:
# array([[ 0.01711561, -1.43139831],
#        [-0.14930917, -0.70168716],
#        [ 0.42284514, -1.63725302],
#        ...,
#        [ 4.75821103,  0.7249539 ],
#        [ 2.87433793, -0.92755963],
#        [ 2.69863245,  1.93420358]])

# %%
kmeans = KMeans(n_clusters=27, random_state=42)
kmeans.fit(X_2D)
# Out:
# C:\Users\mafal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=27, random_state=42)

# %%
clusters = kmeans.predict(X_2D)
clusters
# Out:
# array([ 1, 15, 26, ..., 23, 13,  3])

# %%
labels = np.unique(clusters)

for i in labels:
    plt.scatter(X_2D[clusters == i , 0] , X_2D[clusters == i , 1] , label = i)
plt.legend()
plt.show()

# %%
df = pd.DataFrame(X_2D)
df['cluster'] = clusters
df
# Out:
#              0         1  cluster
# 0     0.017116 -1.431398        1
# 1    -0.149309 -0.701687       15
# 2     0.422845 -1.637253       26
# 3    -0.601282 -1.847688        1
# 4    -0.147348 -0.912003       15
# ...        ...       ...      ...
# 3156  1.173907 -0.585458        8
# 3157  1.196750 -1.703856       20
# 3158  4.758211  0.724954       23
# 3159  2.874338 -0.927560       13
# 3160  2.698632  1.934204        3
#
# [3161 rows x 3 columns]

# %%
cluster_mapping = {i: i for i in range(27)}

# Create a new Series from 'clusters' and apply the mapping
clusters_mapped = pd.Series(clusters).apply(lambda x: cluster_mapping[x])

# If clusters_mapped should replace the original clusters
clusters = clusters_mapped

# %%
# Getting nearest point
from sklearn.metrics import pairwise_distances_argmin_min

X = X_df.drop('cluster', axis=1)
closest, _ = pairwise_distances_argmin_min(X.loc[[132]], X)
# here, this X.loc[[0]] would be representing "a new song"
closest
# Out:
# array([132], dtype=int64)

# %%
results = sp.search(q='artist:Black Midi, ducter', limit=32, type='track')
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3ABlack+Midi%2C+ducter&type=track&offset=0&limit=32',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Hvq85OU8T7Hsd63zNBwaL'},
#        'href': 'https://api.spotify.com/v1/artists/7Hvq85OU8T7Hsd63zNBwaL',
#        'id': '7Hvq85OU8T7Hsd63zNBwaL',
#        'name': 'black midi',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Hvq85OU8T7Hsd63zNBwaL'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5M9SijJoRgczSknq2LaHJN'},
#      'href': 'https://api.spotify.com/v1/albums/5M9SijJoRgczSknq2LaHJN',
#      'id': '5M9SijJoRgczSknq2LaHJN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27359332a8db76d2ee8fbc7d782',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0259332a8db76d2ee8fbc7d782',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485159332a8db76d2ee8fbc7d782',
#        'width': 64}],
#      'name': 'Schlagenheim',
#      'release_date': '2019-06-21',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:5M9SijJoRgczSknq2LaHJN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Hvq85OU8T7Hsd63zNBwaL'},
#       'href': 'https://api.spotify.com/v1/artists/7Hvq85OU8T7Hsd63zNBwaL',
#       'id': '7Hvq85OU8T7Hsd63zNBwaL',
#       'name': 'black midi',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Hvq85OU8T7Hsd63zNBwaL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 402093,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCVZ1900053'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VsGcIEJBSwxMMA2QuaLo1'},
#     'href': 'https://api.spotify.com/v1/tracks/1VsGcIEJBSwxMMA2QuaLo1',
#     'id': '1VsGcIEJBSwxMMA2QuaLo1',
#     'is_local': False,
#     'name': 'Ducter',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5d7f9ad8994f66cfaf5fb1d950428fbfd50b9a93?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:1VsGcIEJBSwxMMA2QuaLo1'}],
#   'limit': 32,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 1}}

# %%
track = pd.json_normalize(sp.audio_features('1VsGcIEJBSwxMMA2QuaLo1'))
track
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.372   0.668    0    -8.182     1       0.0606        0.0115
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0            0.0497     0.112    0.245  148.04  audio_features
#
#                        id                                   uri  \
# 0  1VsGcIEJBSwxMMA2QuaLo1  spotify:track:1VsGcIEJBSwxMMA2QuaLo1
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1VsGcIEJBSwx...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1VsG...       402093
#
#    time_signature
# 0               4

# %%
track = track[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 
                    'duration_ms', 'time_signature']]
track
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.372   0.668    0    -8.182     1       0.0606        0.0115
#
#    instrumentalness  liveness  valence   tempo  duration_ms  time_signature
# 0            0.0497     0.112    0.245  148.04       402093               4

# %%
closest, _ = pairwise_distances_argmin_min(track, X)
# here, this X.loc[[0]] would be representing "a new song"
closest
# Out:
# array([3036], dtype=int64)

# %%
track_features.loc[[3036]]
# Out:
#       danceability   energy  key  loudness  mode  speechiness  acousticness  \
# 3036         0.154  0.00458    0   -28.608     1       0.0448         0.959
#
#       instrumentalness  liveness  valence   tempo            type  \
# 3036             0.952     0.108   0.0918  75.517  audio_features
#
#                           id                                   uri  \
# 3036  0KgSqUAo5E2DZ0xGA2IvnL  spotify:track:0KgSqUAo5E2DZ0xGA2IvnL
#
#                                              track_href  \
# 3036  https://api.spotify.com/v1/tracks/0KgSqUAo5E2D...
#
#                                            analysis_url  duration_ms  \
# 3036  https://api.spotify.com/v1/audio-analysis/0KgS...       402040
#
#       time_signature
# 3036               5

# %%
track_data.loc[track_data['id'] == '0KgSqUAo5E2DZ0xGA2IvnL', ['name', 'artist_name']]
# Out:
#              name artist_name
# 3037  Peace Piece  Sean Shibe

# %%
results = sp.search(q='artist:Arctic Monkeys, Brianstorm', limit=32, type='track')
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3AArctic+Monkeys%2C+Brianstorm&type=track&offset=0&limit=32',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rsQnwaoJHxXJRCDBPkBRw'},
#      'href': 'https://api.spotify.com/v1/albums/6rsQnwaoJHxXJRCDBPkBRw',
#      'id': '6rsQnwaoJHxXJRCDBPkBRw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c8ac83035e9588e8ad34b90',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c8ac83035e9588e8ad34b90',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c8ac83035e9588e8ad34b90',
#        'width': 64}],
#      'name': 'Favourite Worst Nightmare (Standard Version)',
#      'release_date': '2007-04-24',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6rsQnwaoJHxXJRCDBPkBRw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 170253,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700061'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5rTIpPWeO0IL4HWlGWrz5G'},
#     'href': 'https://api.spotify.com/v1/tracks/5rTIpPWeO0IL4HWlGWrz5G',
#     'id': '5rTIpPWeO0IL4HWlGWrz5G',
#     'is_local': False,
#     'name': 'Brianstorm',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/51595b7825f2eb59994cce166c02955972d0ed12?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5rTIpPWeO0IL4HWlGWrz5G'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/48LzgZEtedwMSMSZRWBjiQ'},
#      'href': 'https://api.spotify.com/v1/albums/48LzgZEtedwMSMSZRWBjiQ',
#      'id': '48LzgZEtedwMSMSZRWBjiQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334919e997d9266c04bbff51d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234919e997d9266c04bbff51d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134919e997d9266c04bbff51d',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:48LzgZEtedwMSMSZRWBjiQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 209240,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0j3AgwHeoqudbV5ru5wNwT'},
#     'href': 'https://api.spotify.com/v1/tracks/0j3AgwHeoqudbV5ru5wNwT',
#     'id': '0j3AgwHeoqudbV5ru5wNwT',
#     'is_local': False,
#     'name': 'Temptation Greets You Like Your Naughty Friend',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5b55f8b8c52b086d0a3822042c6a92c93052cbbb?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0j3AgwHeoqudbV5ru5wNwT'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/48LzgZEtedwMSMSZRWBjiQ'},
#      'href': 'https://api.spotify.com/v1/albums/48LzgZEtedwMSMSZRWBjiQ',
#      'id': '48LzgZEtedwMSMSZRWBjiQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334919e997d9266c04bbff51d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234919e997d9266c04bbff51d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134919e997d9266c04bbff51d',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:48LzgZEtedwMSMSZRWBjiQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 182920,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700063'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/07oNd96xlDY0eapjxuBheW'},
#     'href': 'https://api.spotify.com/v1/tracks/07oNd96xlDY0eapjxuBheW',
#     'id': '07oNd96xlDY0eapjxuBheW',
#     'is_local': False,
#     'name': 'What If You Were Right The First Time?',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c989caa5ead976eabc726d0addc800b07f935241?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:07oNd96xlDY0eapjxuBheW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7Heaa0B4KOxdWhSICTR2wE'},
#      'href': 'https://api.spotify.com/v1/albums/7Heaa0B4KOxdWhSICTR2wE',
#      'id': '7Heaa0B4KOxdWhSICTR2wE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273753ff61c73b2861911ce590d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02753ff61c73b2861911ce590d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851753ff61c73b2861911ce590d',
#        'width': 64}],
#      'name': 'Live at the Royal Albert Hall',
#      'release_date': '2020-12-04',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:7Heaa0B4KOxdWhSICTR2wE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 209906,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL2000422'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1RJxGCTCROHUFVWMFOWPYM'},
#     'href': 'https://api.spotify.com/v1/tracks/1RJxGCTCROHUFVWMFOWPYM',
#     'id': '1RJxGCTCROHUFVWMFOWPYM',
#     'is_local': False,
#     'name': 'Brianstorm - Live',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca8312f286458f4e6871b9855fca980d94debdd3?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1RJxGCTCROHUFVWMFOWPYM'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3wes7jJ9Ig44rYtlYGwAh9'},
#      'href': 'https://api.spotify.com/v1/albums/3wes7jJ9Ig44rYtlYGwAh9',
#      'id': '3wes7jJ9Ig44rYtlYGwAh9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de84ee52f85d15d3c2b22d31',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de84ee52f85d15d3c2b22d31',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de84ee52f85d15d3c2b22d31',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-15',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:3wes7jJ9Ig44rYtlYGwAh9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 209226,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3fcJX31CLvMOzcWR0HFn8B'},
#     'href': 'https://api.spotify.com/v1/tracks/3fcJX31CLvMOzcWR0HFn8B',
#     'id': '3fcJX31CLvMOzcWR0HFn8B',
#     'is_local': False,
#     'name': 'Temptation Greets You Like Your Naughty Friend',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d2bd009e8eba5ee0a5a7b263c1bde7908dc7968f?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3fcJX31CLvMOzcWR0HFn8B'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/48LzgZEtedwMSMSZRWBjiQ'},
#      'href': 'https://api.spotify.com/v1/albums/48LzgZEtedwMSMSZRWBjiQ',
#      'id': '48LzgZEtedwMSMSZRWBjiQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334919e997d9266c04bbff51d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234919e997d9266c04bbff51d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134919e997d9266c04bbff51d',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:48LzgZEtedwMSMSZRWBjiQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 172266,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700061'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7k4flQKqNR9OpxOiRKCs0S'},
#     'href': 'https://api.spotify.com/v1/tracks/7k4flQKqNR9OpxOiRKCs0S',
#     'id': '7k4flQKqNR9OpxOiRKCs0S',
#     'is_local': False,
#     'name': 'Brianstorm',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7842a33f9821989cd3efde2772635fdce23bcfc2?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7k4flQKqNR9OpxOiRKCs0S'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3wes7jJ9Ig44rYtlYGwAh9'},
#      'href': 'https://api.spotify.com/v1/albums/3wes7jJ9Ig44rYtlYGwAh9',
#      'id': '3wes7jJ9Ig44rYtlYGwAh9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de84ee52f85d15d3c2b22d31',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de84ee52f85d15d3c2b22d31',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de84ee52f85d15d3c2b22d31',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-15',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:3wes7jJ9Ig44rYtlYGwAh9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 94373,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7acChxuhSqsGWN2b0SHHZe'},
#     'href': 'https://api.spotify.com/v1/tracks/7acChxuhSqsGWN2b0SHHZe',
#     'id': '7acChxuhSqsGWN2b0SHHZe',
#     'is_local': False,
#     'name': "If You Found This It's Probably Too Late",
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2387457a206294f3e64712e2fda1b244693fc24e?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7acChxuhSqsGWN2b0SHHZe'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jFTTB7q8o1KYSugIF9iQN'},
#      'href': 'https://api.spotify.com/v1/albums/5jFTTB7q8o1KYSugIF9iQN',
#      'id': '5jFTTB7q8o1KYSugIF9iQN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27309281262f661be3726612a3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0209281262f661be3726612a3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485109281262f661be3726612a3f',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:5jFTTB7q8o1KYSugIF9iQN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 94373,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3LLfrdlpYprGtqf0cOmJu9'},
#     'href': 'https://api.spotify.com/v1/tracks/3LLfrdlpYprGtqf0cOmJu9',
#     'id': '3LLfrdlpYprGtqf0cOmJu9',
#     'is_local': False,
#     'name': "If You Found This It's Probably Too Late",
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2387457a206294f3e64712e2fda1b244693fc24e?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3LLfrdlpYprGtqf0cOmJu9'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3wes7jJ9Ig44rYtlYGwAh9'},
#      'href': 'https://api.spotify.com/v1/albums/3wes7jJ9Ig44rYtlYGwAh9',
#      'id': '3wes7jJ9Ig44rYtlYGwAh9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de84ee52f85d15d3c2b22d31',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de84ee52f85d15d3c2b22d31',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de84ee52f85d15d3c2b22d31',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-15',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:3wes7jJ9Ig44rYtlYGwAh9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 182920,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700063'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3acb2sXcXrUQGFYJE2qHs8'},
#     'href': 'https://api.spotify.com/v1/tracks/3acb2sXcXrUQGFYJE2qHs8',
#     'id': '3acb2sXcXrUQGFYJE2qHs8',
#     'is_local': False,
#     'name': 'What If You Were Right The First Time?',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16c0498f93119c9c4abd3b57bc29f2f66ed3413b?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3acb2sXcXrUQGFYJE2qHs8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3wes7jJ9Ig44rYtlYGwAh9'},
#      'href': 'https://api.spotify.com/v1/albums/3wes7jJ9Ig44rYtlYGwAh9',
#      'id': '3wes7jJ9Ig44rYtlYGwAh9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de84ee52f85d15d3c2b22d31',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de84ee52f85d15d3c2b22d31',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de84ee52f85d15d3c2b22d31',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-15',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:3wes7jJ9Ig44rYtlYGwAh9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 172866,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700061'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6RUwlBcK959CotJDxHh0QU'},
#     'href': 'https://api.spotify.com/v1/tracks/6RUwlBcK959CotJDxHh0QU',
#     'id': '6RUwlBcK959CotJDxHh0QU',
#     'is_local': False,
#     'name': 'Brianstorm',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7707da4b7c6da930804e6c28bfe5d037c29ec0e3?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6RUwlBcK959CotJDxHh0QU'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jFTTB7q8o1KYSugIF9iQN'},
#      'href': 'https://api.spotify.com/v1/albums/5jFTTB7q8o1KYSugIF9iQN',
#      'id': '5jFTTB7q8o1KYSugIF9iQN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27309281262f661be3726612a3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0209281262f661be3726612a3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485109281262f661be3726612a3f',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:5jFTTB7q8o1KYSugIF9iQN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 172866,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700061'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3diD9FCmSlagvI4OtGUzIe'},
#     'href': 'https://api.spotify.com/v1/tracks/3diD9FCmSlagvI4OtGUzIe',
#     'id': '3diD9FCmSlagvI4OtGUzIe',
#     'is_local': False,
#     'name': 'Brianstorm',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7707da4b7c6da930804e6c28bfe5d037c29ec0e3?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3diD9FCmSlagvI4OtGUzIe'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jFTTB7q8o1KYSugIF9iQN'},
#      'href': 'https://api.spotify.com/v1/albums/5jFTTB7q8o1KYSugIF9iQN',
#      'id': '5jFTTB7q8o1KYSugIF9iQN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27309281262f661be3726612a3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0209281262f661be3726612a3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485109281262f661be3726612a3f',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:5jFTTB7q8o1KYSugIF9iQN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 209226,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7pApE79eykYG9DL72XdCJn'},
#     'href': 'https://api.spotify.com/v1/tracks/7pApE79eykYG9DL72XdCJn',
#     'id': '7pApE79eykYG9DL72XdCJn',
#     'is_local': False,
#     'name': 'Temptation Greets You Like Your Naughty Friend',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d2bd009e8eba5ee0a5a7b263c1bde7908dc7968f?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7pApE79eykYG9DL72XdCJn'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#        'id': '7Ln80lUS6He07XvHI8qqHH',
#        'name': 'Arctic Monkeys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jFTTB7q8o1KYSugIF9iQN'},
#      'href': 'https://api.spotify.com/v1/albums/5jFTTB7q8o1KYSugIF9iQN',
#      'id': '5jFTTB7q8o1KYSugIF9iQN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27309281262f661be3726612a3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0209281262f661be3726612a3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485109281262f661be3726612a3f',
#        'width': 64}],
#      'name': 'Brianstorm',
#      'release_date': '2007-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:5jFTTB7q8o1KYSugIF9iQN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 182920,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL0700063'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2SFZ4fnjZ5LT30LOBOUJre'},
#     'href': 'https://api.spotify.com/v1/tracks/2SFZ4fnjZ5LT30LOBOUJre',
#     'id': '2SFZ4fnjZ5LT30LOBOUJre',
#     'is_local': False,
#     'name': 'What If You Were Right The First Time?',
#     'popularity': 18,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16c0498f93119c9c4abd3b57bc29f2f66ed3413b?cid=c43ae4f18c0d4b2c8b04c93649fa4b72',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2SFZ4fnjZ5LT30LOBOUJre'}],
#   'limit': 32,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 13}}

# %%
track = pd.json_normalize(sp.audio_features('6RUwlBcK959CotJDxHh0QU'))
track
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.42   0.974    1    -4.706     1        0.191      0.000082
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00155    0.0871    0.463  165.182  audio_features
#
#                        id                                   uri  \
# 0  6RUwlBcK959CotJDxHh0QU  spotify:track:6RUwlBcK959CotJDxHh0QU
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6RUwlBcK959C...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6RUw...       172867
#
#    time_signature
# 0               4

# %%
track = track[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 
                    'duration_ms', 'time_signature']]
track
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.42   0.974    1    -4.706     1        0.191      0.000082
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0           0.00155    0.0871    0.463  165.182       172867               4

# %%
closest, _ = pairwise_distances_argmin_min(track, X)
# here, this X.loc[[0]] would be representing "a new song"
closest
# Out:
# array([63], dtype=int64)

# %%
track_features.loc[[63]]
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 63         0.605   0.819    7    -5.932     0       0.0291        0.0184
#
#     instrumentalness  liveness  valence    tempo            type  \
# 63             0.158     0.101     0.76  120.009  audio_features
#
#                         id                                   uri  \
# 63  1FE3y5rW4l9I7prqRLnLi4  spotify:track:1FE3y5rW4l9I7prqRLnLi4
#
#                                            track_href  \
# 63  https://api.spotify.com/v1/tracks/1FE3y5rW4l9I...
#
#                                          analysis_url  duration_ms  \
# 63  https://api.spotify.com/v1/audio-analysis/1FE3...       172868
#
#     time_signature
# 63               4

# %%
track_data.loc[track_data['id'] == '1FE3y5rW4l9I7prqRLnLi4', ['name', 'artist_name']]
# Out:
#            name artist_name
# 53    Bang Bang       Momma
# 1191  Bang Bang       Momma
